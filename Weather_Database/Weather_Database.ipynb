# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

import time
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Build the basic URL for the OpenWeatherMap with my weather_api_key added to the URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_weather = city_weather["weather"][0]["description"]
     
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atar
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | tingrela
# City not found. Skipping...
# Processing Record 4 of Set 1 | champerico
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | socorro
# Processing Record 7 of Set 1 | labuhan
# Processing Record 8 of Set 1 | manggar
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | play cu
# City not found. Skipping...
# Processing Record 11 of Set 1 | moba
# Processing Record 12 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 1 | aswan
# Processing Record 14 of Set 1 | nara
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | avera
# Processing Record 18 of Set 1 | kapchorwa
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | petrykiv
# Processing Record 22 of Set 1 | whitehorse
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | hualmay
# Processing Record 26 of Set 1 | la ronge
# Processing Record 27 of Set 1 | akdepe
# Processing Record 28 of Set 1 | aksay
# Processing Record 29 of Set 1 | trogir
# Processing Record 30 of Set 1 | ucluelet
# Processing Record 31 of Set 1 | deqing
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | husavik
# Processing Record 34 of Set 1 | luocheng
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | strezhevoy
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | san quintin
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | comodoro rivadavia
# Processing Record 50 of Set 1 | kiruna
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | ostrovnoy
# Processing Record 3 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | lang son
# Processing Record 6 of Set 2 | muhos
# Processing Record 7 of Set 2 | sorong
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | datong
# Processing Record 10 of Set 2 | norman wells
# Processing Record 11 of Set 2 | chernyshevskiy
# Processing Record 12 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 2 | presidencia roque saenz pena
# Processing Record 14 of Set 2 | pangnirtung
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | ponta delgada
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | bryant
# Processing Record 19 of Set 2 | bardiyah
# Processing Record 20 of Set 2 | cochabamba
# Processing Record 21 of Set 2 | port augusta
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 24 of Set 2 | tynda
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | plettenberg bay
# Processing Record 28 of Set 2 | igrim
# Processing Record 29 of Set 2 | bambous virieux
# Processing Record 30 of Set 2 | iskateley
# Processing Record 31 of Set 2 | klaksvik
# Processing Record 32 of Set 2 | le port
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | vakhrushev
# Processing Record 35 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | kahului
# Processing Record 38 of Set 2 | lavrentiya
# Processing Record 39 of Set 2 | cabo san lucas
# Processing Record 40 of Set 2 | katsuura
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | dudinka
# Processing Record 44 of Set 2 | tilichiki
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | saint-joseph
# Processing Record 47 of Set 2 | alamogordo
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | talnakh
# Processing Record 50 of Set 2 | kruisfontein
# Processing Record 1 of Set 3 | ukiah
# Processing Record 2 of Set 3 | sao miguel do araguaia
# Processing Record 3 of Set 3 | sabang
# Processing Record 4 of Set 3 | havre
# Processing Record 5 of Set 3 | andalan
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | wajima
# Processing Record 8 of Set 3 | manaus
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | srednekolymsk
# Processing Record 11 of Set 3 | vao
# Processing Record 12 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | saint anthony
# Processing Record 14 of Set 3 | kandrian
# Processing Record 15 of Set 3 | wuhan
# Processing Record 16 of Set 3 | sioux lookout
# Processing Record 17 of Set 3 | aparecida do taboado
# Processing Record 18 of Set 3 | mount gambier
# Processing Record 19 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 3 | tasiilaq
# Processing Record 21 of Set 3 | marsa matruh
# Processing Record 22 of Set 3 | khandbari
# Processing Record 23 of Set 3 | pizarro
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 3 | ambilobe
# Processing Record 27 of Set 3 | tual
# Processing Record 28 of Set 3 | cockburn town
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | pyu
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | phan thiet
# Processing Record 34 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 3 | geraldton
# Processing Record 36 of Set 3 | goderich
# Processing Record 37 of Set 3 | georgetown
# Processing Record 38 of Set 3 | beringovskiy
# Processing Record 39 of Set 3 | saint george
# Processing Record 40 of Set 3 | sakakah
# Processing Record 41 of Set 3 | novosheshminsk
# Processing Record 42 of Set 3 | santa maria
# Processing Record 43 of Set 3 | angoche
# Processing Record 44 of Set 3 | teya
# Processing Record 45 of Set 3 | daru
# Processing Record 46 of Set 3 | touros
# Processing Record 47 of Set 3 | talas
# Processing Record 48 of Set 3 | raudeberg
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | hamilton
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | half moon bay
# Processing Record 3 of Set 4 | hecun
# Processing Record 4 of Set 4 | french harbor
# Processing Record 5 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 4 | ola
# Processing Record 7 of Set 4 | senmonorom
# City not found. Skipping...
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | awbari
# Processing Record 10 of Set 4 | ibotirama
# Processing Record 11 of Set 4 | ponta do sol
# Processing Record 12 of Set 4 | dunedin
# Processing Record 13 of Set 4 | lebu
# Processing Record 14 of Set 4 | qaanaaq
# Processing Record 15 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 4 | riyadh
# Processing Record 17 of Set 4 | russell
# Processing Record 18 of Set 4 | tombouctou
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | blackfoot
# Processing Record 21 of Set 4 | hobyo
# Processing Record 22 of Set 4 | shirokiy
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | port hedland
# Processing Record 25 of Set 4 | tuktoyaktuk
# Processing Record 26 of Set 4 | nyagan
# Processing Record 27 of Set 4 | dikson
# Processing Record 28 of Set 4 | fortuna
# Processing Record 29 of Set 4 | kavieng
# Processing Record 30 of Set 4 | coos bay
# Processing Record 31 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 4 | bathsheba
# Processing Record 33 of Set 4 | vaini
# Processing Record 34 of Set 4 | waddan
# Processing Record 35 of Set 4 | bengkulu
# Processing Record 36 of Set 4 | arlit
# Processing Record 37 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 4 | port alfred
# Processing Record 39 of Set 4 | coyutla
# Processing Record 40 of Set 4 | ormara
# Processing Record 41 of Set 4 | san ignacio
# Processing Record 42 of Set 4 | qibili
# City not found. Skipping...
# Processing Record 43 of Set 4 | sobolevo
# Processing Record 44 of Set 4 | mahebourg
# Processing Record 45 of Set 4 | noumea
# Processing Record 46 of Set 4 | mount isa
# Processing Record 47 of Set 4 | shimoda
# Processing Record 48 of Set 4 | buala
# Processing Record 49 of Set 4 | ardahan
# Processing Record 50 of Set 4 | berlevag
# Processing Record 1 of Set 5 | margate
# Processing Record 2 of Set 5 | malpe
# Processing Record 3 of Set 5 | coihaique
# Processing Record 4 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 5 | bahia honda
# Processing Record 6 of Set 5 | rio grande
# Processing Record 7 of Set 5 | lages
# Processing Record 8 of Set 5 | vanavara
# Processing Record 9 of Set 5 | puerto madryn
# Processing Record 10 of Set 5 | vostok
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | bure
# Processing Record 13 of Set 5 | griffith
# Processing Record 14 of Set 5 | kochevo
# Processing Record 15 of Set 5 | ocampo
# Processing Record 16 of Set 5 | nelson bay
# Processing Record 17 of Set 5 | rassvet
# Processing Record 18 of Set 5 | mana
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | taoudenni
# Processing Record 21 of Set 5 | capitao poco
# Processing Record 22 of Set 5 | kenai
# Processing Record 23 of Set 5 | dingle
# Processing Record 24 of Set 5 | saleilua
# City not found. Skipping...
# Processing Record 25 of Set 5 | sibiti
# Processing Record 26 of Set 5 | kavaratti
# Processing Record 27 of Set 5 | el alto
# Processing Record 28 of Set 5 | lorengau
# Processing Record 29 of Set 5 | arraial do cabo
# Processing Record 30 of Set 5 | biak
# Processing Record 31 of Set 5 | mubi
# Processing Record 32 of Set 5 | gold coast
# Processing Record 33 of Set 5 | coquimbo
# Processing Record 34 of Set 5 | toppenish
# Processing Record 35 of Set 5 | port hardy
# Processing Record 36 of Set 5 | saskylakh
# Processing Record 37 of Set 5 | coahuayana
# Processing Record 38 of Set 5 | mezen
# Processing Record 39 of Set 5 | panjakent
# Processing Record 40 of Set 5 | qaqortoq
# Processing Record 41 of Set 5 | kodiak
# Processing Record 42 of Set 5 | sao jose da coroa grande
# Processing Record 43 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 44 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 5 | ilo
# Processing Record 46 of Set 5 | dubinino
# Processing Record 47 of Set 5 | pevek
# Processing Record 48 of Set 5 | ligatne
# Processing Record 49 of Set 5 | dekoa
# City not found. Skipping...
# Processing Record 50 of Set 5 | faanui
# Processing Record 1 of Set 6 | quelimane
# Processing Record 2 of Set 6 | tura
# Processing Record 3 of Set 6 | dhemaji
# Processing Record 4 of Set 6 | sarankhola
# Processing Record 5 of Set 6 | kondinskoye
# Processing Record 6 of Set 6 | willowmore
# Processing Record 7 of Set 6 | byron bay
# Processing Record 8 of Set 6 | victoria
# Processing Record 9 of Set 6 | upernavik
# Processing Record 10 of Set 6 | souillac
# Processing Record 11 of Set 6 | fairbanks
# Processing Record 12 of Set 6 | ushtobe
# Processing Record 13 of Set 6 | indiana
# Processing Record 14 of Set 6 | tyubuk
# Processing Record 15 of Set 6 | aklavik
# Processing Record 16 of Set 6 | tafresh
# Processing Record 17 of Set 6 | san patricio
# Processing Record 18 of Set 6 | abapo
# Processing Record 19 of Set 6 | barranca de upia
# Processing Record 20 of Set 6 | mangan
# Processing Record 21 of Set 6 | ritchie
# Processing Record 22 of Set 6 | campbellton
# Processing Record 23 of Set 6 | poum
# Processing Record 24 of Set 6 | orsha
# Processing Record 25 of Set 6 | idenao
# Processing Record 26 of Set 6 | bethel
# Processing Record 27 of Set 6 | verkhnevilyuysk
# Processing Record 28 of Set 6 | hofn
# Processing Record 29 of Set 6 | ahipara
# Processing Record 30 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 6 | hirara
# Processing Record 32 of Set 6 | asau
# Processing Record 33 of Set 6 | samarai
# Processing Record 34 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 6 | bubaque
# Processing Record 37 of Set 6 | terrasini
# Processing Record 38 of Set 6 | north myrtle beach
# Processing Record 39 of Set 6 | codrington
# Processing Record 40 of Set 6 | portobelo
# Processing Record 41 of Set 6 | yarmouth
# Processing Record 42 of Set 6 | pacific grove
# Processing Record 43 of Set 6 | salalah
# Processing Record 44 of Set 6 | semenivka
# Processing Record 45 of Set 6 | nioro
# Processing Record 46 of Set 6 | toungoo
# City not found. Skipping...
# Processing Record 47 of Set 6 | mount pleasant
# Processing Record 48 of Set 6 | airai
# Processing Record 49 of Set 6 | nome
# Processing Record 50 of Set 6 | homer
# Processing Record 1 of Set 7 | vardo
# Processing Record 2 of Set 7 | meulaboh
# Processing Record 3 of Set 7 | guerrero negro
# Processing Record 4 of Set 7 | alofi
# Processing Record 5 of Set 7 | zhangye
# Processing Record 6 of Set 7 | saldanha
# Processing Record 7 of Set 7 | katangli
# Processing Record 8 of Set 7 | kitimat
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | paita
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | sarab
# Processing Record 13 of Set 7 | muroto
# Processing Record 14 of Set 7 | barcelos
# Processing Record 15 of Set 7 | porto santo
# Processing Record 16 of Set 7 | chara
# Processing Record 17 of Set 7 | san vicente
# Processing Record 18 of Set 7 | maarianhamina
# Processing Record 19 of Set 7 | slavonski brod
# Processing Record 20 of Set 7 | sitka
# Processing Record 21 of Set 7 | saint john
# Processing Record 22 of Set 7 | witu
# Processing Record 23 of Set 7 | lompoc
# Processing Record 24 of Set 7 | newport
# Processing Record 25 of Set 7 | kortkeros
# Processing Record 26 of Set 7 | tiznit
# Processing Record 27 of Set 7 | vilhena
# Processing Record 28 of Set 7 | springdale
# Processing Record 29 of Set 7 | urozhaynoye
# Processing Record 30 of Set 7 | hovd
# Processing Record 31 of Set 7 | luderitz
# Processing Record 32 of Set 7 | mozelos
# Processing Record 33 of Set 7 | maralal
# Processing Record 34 of Set 7 | llangefni
# Processing Record 35 of Set 7 | kinel
# Processing Record 36 of Set 7 | amarillo
# Processing Record 37 of Set 7 | tabuk
# Processing Record 38 of Set 7 | changli
# Processing Record 39 of Set 7 | havoysund
# Processing Record 40 of Set 7 | namtsy
# Processing Record 41 of Set 7 | kargasok
# Processing Record 42 of Set 7 | tupancireta
# Processing Record 43 of Set 7 | te anau
# Processing Record 44 of Set 7 | tete
# Processing Record 45 of Set 7 | college
# Processing Record 46 of Set 7 | chilca
# Processing Record 47 of Set 7 | liwale
# Processing Record 48 of Set 7 | burica
# City not found. Skipping...
# Processing Record 49 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 50 of Set 7 | diamantino
# Processing Record 1 of Set 8 | mananjary
# Processing Record 2 of Set 8 | omboue
# Processing Record 3 of Set 8 | cayenne
# Processing Record 4 of Set 8 | am timan
# Processing Record 5 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 8 | tomsk
# Processing Record 7 of Set 8 | maumere
# Processing Record 8 of Set 8 | mildura
# Processing Record 9 of Set 8 | turinsk
# Processing Record 10 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 11 of Set 8 | camopi
# Processing Record 12 of Set 8 | kungalv
# Processing Record 13 of Set 8 | pangkalanbuun
# Processing Record 14 of Set 8 | yumbe
# Processing Record 15 of Set 8 | juba
# Processing Record 16 of Set 8 | hrubieszow
# Processing Record 17 of Set 8 | deputatskiy
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | raduzhnyy
# Processing Record 20 of Set 8 | covington
# Processing Record 21 of Set 8 | salta
# Processing Record 22 of Set 8 | melfort
# Processing Record 23 of Set 8 | yulara
# Processing Record 24 of Set 8 | isla mujeres
# Processing Record 25 of Set 8 | chuy
# Processing Record 26 of Set 8 | tessalit
# Processing Record 27 of Set 8 | majagual
# Processing Record 28 of Set 8 | port-gentil
# Processing Record 29 of Set 8 | espera feliz
# Processing Record 30 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 8 | esperance
# Processing Record 33 of Set 8 | oropesa
# Processing Record 34 of Set 8 | muncar
# Processing Record 35 of Set 8 | ilinskiy
# Processing Record 36 of Set 8 | inirida
# Processing Record 37 of Set 8 | kaitangata
# Processing Record 38 of Set 8 | santa isabel
# Processing Record 39 of Set 8 | vanimo
# Processing Record 40 of Set 8 | caraquet
# Processing Record 41 of Set 8 | isilkul
# Processing Record 42 of Set 8 | yenotayevka
# Processing Record 43 of Set 8 | ayagoz
# Processing Record 44 of Set 8 | nusaybin
# Processing Record 45 of Set 8 | chynov
# Processing Record 46 of Set 8 | lempaala
# Processing Record 47 of Set 8 | abu samrah
# Processing Record 48 of Set 8 | cherskiy
# Processing Record 49 of Set 8 | amuntai
# Processing Record 50 of Set 8 | altamira
# Processing Record 1 of Set 9 | mayor pablo lagerenza
# Processing Record 2 of Set 9 | godo
# Processing Record 3 of Set 9 | mahibadhoo
# Processing Record 4 of Set 9 | do rud
# City not found. Skipping...
# Processing Record 5 of Set 9 | praia da vitoria
# Processing Record 6 of Set 9 | umm kaddadah
# Processing Record 7 of Set 9 | bud
# Processing Record 8 of Set 9 | kenora
# Processing Record 9 of Set 9 | clyde river
# Processing Record 10 of Set 9 | joshimath
# Processing Record 11 of Set 9 | brae
# Processing Record 12 of Set 9 | kropotkin
# Processing Record 13 of Set 9 | pimenta bueno
# Processing Record 14 of Set 9 | ust-maya
# Processing Record 15 of Set 9 | santa lucia
# Processing Record 16 of Set 9 | cachoeiro de itapemirim
# Processing Record 17 of Set 9 | shimanovsk
# Processing Record 18 of Set 9 | manaure
# Processing Record 19 of Set 9 | ilulissat
# Processing Record 20 of Set 9 | pangody
# Processing Record 21 of Set 9 | keningau
# Processing Record 22 of Set 9 | tukrah
# Processing Record 23 of Set 9 | umm lajj
# Processing Record 24 of Set 9 | temiscaming
# Processing Record 25 of Set 9 | davila
# Processing Record 26 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 9 | abilene
# Processing Record 28 of Set 9 | labuan
# Processing Record 29 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 9 | santa cruz
# Processing Record 31 of Set 9 | haines junction
# Processing Record 32 of Set 9 | adrar
# Processing Record 33 of Set 9 | maridi
# Processing Record 34 of Set 9 | kamenka
# Processing Record 35 of Set 9 | taltal
# Processing Record 36 of Set 9 | umarkot
# Processing Record 37 of Set 9 | panama city
# Processing Record 38 of Set 9 | vestmannaeyjar
# Processing Record 39 of Set 9 | tomatlan
# Processing Record 40 of Set 9 | chudovo
# Processing Record 41 of Set 9 | acarau
# Processing Record 42 of Set 9 | kristiinankaupunki
# Processing Record 43 of Set 9 | tongzi
# Processing Record 44 of Set 9 | nesna
# Processing Record 45 of Set 9 | vila velha
# Processing Record 46 of Set 9 | lasa
# Processing Record 47 of Set 9 | santo domingo
# Processing Record 48 of Set 9 | kalinovskaya
# Processing Record 49 of Set 9 | auki
# Processing Record 50 of Set 9 | sechura
# Processing Record 1 of Set 10 | kaeo
# Processing Record 2 of Set 10 | tabou
# Processing Record 3 of Set 10 | houston
# Processing Record 4 of Set 10 | olga
# Processing Record 5 of Set 10 | makokou
# Processing Record 6 of Set 10 | jurm
# Processing Record 7 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 10 | egvekinot
# Processing Record 9 of Set 10 | san felipe
# Processing Record 10 of Set 10 | shelburne
# Processing Record 11 of Set 10 | jinchang
# Processing Record 12 of Set 10 | bratsk
# Processing Record 13 of Set 10 | ayan
# Processing Record 14 of Set 10 | chibuto
# Processing Record 15 of Set 10 | westport
# Processing Record 16 of Set 10 | ust-kulom
# Processing Record 17 of Set 10 | flin flon
# Processing Record 18 of Set 10 | envira
# Processing Record 19 of Set 10 | karwar
# Processing Record 20 of Set 10 | honiara
# Processing Record 21 of Set 10 | belaya gora
# Processing Record 22 of Set 10 | pomabamba
# Processing Record 23 of Set 10 | xuddur
# Processing Record 24 of Set 10 | severobaykalsk
# Processing Record 25 of Set 10 | pakala
# Processing Record 26 of Set 10 | ponnani
# Processing Record 27 of Set 10 | waipawa
# Processing Record 28 of Set 10 | teguise
# Processing Record 29 of Set 10 | makinsk
# Processing Record 30 of Set 10 | ballina
# Processing Record 31 of Set 10 | clermont
# Processing Record 32 of Set 10 | hay river
# Processing Record 33 of Set 10 | siocon
# Processing Record 34 of Set 10 | prainha
# Processing Record 35 of Set 10 | bac
# Processing Record 36 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 10 | bonavista
# Processing Record 38 of Set 10 | sabha
# Processing Record 39 of Set 10 | quatre cocos
# Processing Record 40 of Set 10 | alabaster
# Processing Record 41 of Set 10 | kununurra
# Processing Record 42 of Set 10 | camabatela
# Processing Record 43 of Set 10 | praya
# Processing Record 44 of Set 10 | balikpapan
# Processing Record 45 of Set 10 | ushibuka
# Processing Record 46 of Set 10 | cadillac
# Processing Record 47 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 10 | loukhi
# Processing Record 49 of Set 10 | mayya
# Processing Record 50 of Set 10 | pag
# Processing Record 1 of Set 11 | korla
# Processing Record 2 of Set 11 | ambon
# Processing Record 3 of Set 11 | alice springs
# Processing Record 4 of Set 11 | eenhana
# Processing Record 5 of Set 11 | ouallam
# Processing Record 6 of Set 11 | klyuchi
# Processing Record 7 of Set 11 | nanyang
# Processing Record 8 of Set 11 | buchanan
# Processing Record 9 of Set 11 | ranong
# Processing Record 10 of Set 11 | carnarvon
# Processing Record 11 of Set 11 | wad rawah
# Processing Record 12 of Set 11 | krasnoufimsk
# Processing Record 13 of Set 11 | workington
# Processing Record 14 of Set 11 | zhezkazgan
# Processing Record 15 of Set 11 | montepuez
# Processing Record 16 of Set 11 | weston
# Processing Record 17 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 18 of Set 11 | dergaon
# Processing Record 19 of Set 11 | kalevala
# Processing Record 20 of Set 11 | port-cartier
# Processing Record 21 of Set 11 | gwadar
# Processing Record 22 of Set 11 | senno
# Processing Record 23 of Set 11 | rocha
# Processing Record 24 of Set 11 | santa isabel do rio negro
# Processing Record 25 of Set 11 | pokhara
# Processing Record 26 of Set 11 | tevaitoa
# Processing Record 27 of Set 11 | crixas
# Processing Record 28 of Set 11 | fort wellington
# Processing Record 29 of Set 11 | kudahuvadhoo
# Processing Record 30 of Set 11 | lerwick
# Processing Record 31 of Set 11 | dorado
# Processing Record 32 of Set 11 | mendeleyevsk
# Processing Record 33 of Set 11 | constitucion
# Processing Record 34 of Set 11 | lakes entrance
# Processing Record 35 of Set 11 | baykit
# Processing Record 36 of Set 11 | gobabis
# Processing Record 37 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 11 | chegdomyn
# Processing Record 39 of Set 11 | yueyang
# Processing Record 40 of Set 11 | archidona
# Processing Record 41 of Set 11 | mayo
# Processing Record 42 of Set 11 | ancud
# Processing Record 43 of Set 11 | hesla
# Processing Record 44 of Set 11 | lebyazhye
# Processing Record 45 of Set 11 | changzhou
# Processing Record 46 of Set 11 | leh
# Processing Record 47 of Set 11 | khlung
# Processing Record 48 of Set 11 | collecchio
# Processing Record 49 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 11 | mandalgovi
# Processing Record 1 of Set 12 | yar-sale
# Processing Record 2 of Set 12 | lugovoy
# Processing Record 3 of Set 12 | upata
# Processing Record 4 of Set 12 | chaman
# Processing Record 5 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 12 | ust-kuyga
# Processing Record 7 of Set 12 | ruzhyn
# Processing Record 8 of Set 12 | vicuna
# Processing Record 9 of Set 12 | natal
# Processing Record 10 of Set 12 | molde
# Processing Record 11 of Set 12 | araouane
# Processing Record 12 of Set 12 | royal palm beach
# Processing Record 13 of Set 12 | the pas
# Processing Record 14 of Set 12 | smithers
# Processing Record 15 of Set 12 | dimbokro
# Processing Record 16 of Set 12 | chippewa falls
# Processing Record 17 of Set 12 | sherghati
# Processing Record 18 of Set 12 | mulchen
# Processing Record 19 of Set 12 | turukhansk
# Processing Record 20 of Set 12 | izhevsk
# Processing Record 21 of Set 12 | dagana
# Processing Record 22 of Set 12 | fort nelson
# Processing Record 23 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 24 of Set 12 | vrutky
# Processing Record 25 of Set 12 | elk city
# Processing Record 26 of Set 12 | vrangel
# Processing Record 27 of Set 12 | mayumba
# Processing Record 28 of Set 12 | sao joao da barra
# Processing Record 29 of Set 12 | lubango
# Processing Record 30 of Set 12 | ayorou
# Processing Record 31 of Set 12 | banda aceh
# Processing Record 32 of Set 12 | batagay-alyta
# Processing Record 33 of Set 12 | vila do maio
# Processing Record 34 of Set 12 | wasilla
# Processing Record 35 of Set 12 | atocha
# Processing Record 36 of Set 12 | gizo
# Processing Record 37 of Set 12 | adiake
# Processing Record 38 of Set 12 | belmonte
# Processing Record 39 of Set 12 | anito
# Processing Record 40 of Set 12 | kulgam
# Processing Record 41 of Set 12 | odweyne
# Processing Record 42 of Set 12 | kusa
# Processing Record 43 of Set 12 | yei
# Processing Record 44 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 12 | sonkovo
# Processing Record 46 of Set 12 | panguna
# Processing Record 47 of Set 12 | madera
# Processing Record 48 of Set 12 | isangel
# Processing Record 49 of Set 12 | tabas
# Processing Record 50 of Set 12 | denpasar
# Processing Record 1 of Set 13 | pedernales
# Processing Record 2 of Set 13 | hervey bay
# Processing Record 3 of Set 13 | ginir
# Processing Record 4 of Set 13 | luba
# Processing Record 5 of Set 13 | rockland
# Processing Record 6 of Set 13 | santa catalina
# Processing Record 7 of Set 13 | rosario
# Processing Record 8 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 13 | beaverlodge
# Processing Record 10 of Set 13 | petatlan
# Processing Record 11 of Set 13 | los chiles
# Processing Record 12 of Set 13 | key west
# Processing Record 13 of Set 13 | henties bay
# Processing Record 14 of Set 13 | kabalo
# Processing Record 15 of Set 13 | puerto cabezas
# Processing Record 16 of Set 13 | prince rupert
# Processing Record 17 of Set 13 | colares
# Processing Record 18 of Set 13 | oranjestad
# Processing Record 19 of Set 13 | sawang daen din
# Processing Record 20 of Set 13 | yidu
# Processing Record 21 of Set 13 | fairmont
# Processing Record 22 of Set 13 | matara
# Processing Record 23 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 13 | chabahar
# Processing Record 25 of Set 13 | pathein
# Processing Record 26 of Set 13 | sacramento
# Processing Record 27 of Set 13 | bukama
# Processing Record 28 of Set 13 | chimore
# Processing Record 29 of Set 13 | maragogi
# Processing Record 30 of Set 13 | hershey
# Processing Record 31 of Set 13 | aliwal north
# Processing Record 32 of Set 13 | toora-khem
# Processing Record 33 of Set 13 | berdigestyakh
# Processing Record 34 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 13 | ciras
# City not found. Skipping...
# Processing Record 36 of Set 13 | mitsamiouli
# Processing Record 37 of Set 13 | sur
# Processing Record 38 of Set 13 | valentin gomez farias
# Processing Record 39 of Set 13 | takoradi
# Processing Record 40 of Set 13 | fukue
# Processing Record 41 of Set 13 | dujuma
# City not found. Skipping...
# Processing Record 42 of Set 13 | stornoway
# Processing Record 43 of Set 13 | northam
# Processing Record 44 of Set 13 | lovozero
# Processing Record 45 of Set 13 | general roca
# Processing Record 46 of Set 13 | arrecife
# Processing Record 47 of Set 13 | pontianak
# Processing Record 48 of Set 13 | koroni
# Processing Record 49 of Set 13 | kutum
# Processing Record 50 of Set 13 | leningradskiy
# Processing Record 1 of Set 14 | dzhebariki-khaya
# Processing Record 2 of Set 14 | kadoma
# Processing Record 3 of Set 14 | laranjeiras do sul
# Processing Record 4 of Set 14 | bereznik
# Processing Record 5 of Set 14 | vesyegonsk
# Processing Record 6 of Set 14 | yurga
# Processing Record 7 of Set 14 | faya
# Processing Record 8 of Set 14 | rosarito
# Processing Record 9 of Set 14 | arman
# Processing Record 10 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 14 | yingshang
# City not found. Skipping...
# Processing Record 12 of Set 14 | el tigre
# Processing Record 13 of Set 14 | pechora
# Processing Record 14 of Set 14 | rio gallegos
# Processing Record 15 of Set 14 | mudgal
# Processing Record 16 of Set 14 | praia
# Processing Record 17 of Set 14 | marzuq
# Processing Record 18 of Set 14 | mae ramat
# Processing Record 19 of Set 14 | areni
# Processing Record 20 of Set 14 | xinxiang
# Processing Record 21 of Set 14 | narasannapeta
# Processing Record 22 of Set 14 | belomorsk
# Processing Record 23 of Set 14 | port blair
# Processing Record 24 of Set 14 | tinskoy
# Processing Record 25 of Set 14 | mangaluru
# Processing Record 26 of Set 14 | soyo
# Processing Record 27 of Set 14 | anzio
# Processing Record 28 of Set 14 | lukang
# Processing Record 29 of Set 14 | azle
# Processing Record 30 of Set 14 | de-kastri
# Processing Record 31 of Set 14 | revda
# Processing Record 32 of Set 14 | vanderhoof
# Processing Record 33 of Set 14 | atasu
# Processing Record 34 of Set 14 | merrill
# Processing Record 35 of Set 14 | hambantota
# Processing Record 36 of Set 14 | sandwich
# Processing Record 37 of Set 14 | nantucket
# Processing Record 38 of Set 14 | thunder bay
# Processing Record 39 of Set 14 | west wendover
# Processing Record 40 of Set 14 | roald
# Processing Record 41 of Set 14 | iralaya
# Processing Record 42 of Set 14 | isla vista
# Processing Record 43 of Set 14 | karratha
# Processing Record 44 of Set 14 | alcains
# Processing Record 45 of Set 14 | sao lourenco do oeste
# Processing Record 46 of Set 14 | nadvoitsy
# Processing Record 47 of Set 14 | erkelenz
# Processing Record 48 of Set 14 | young
# Processing Record 49 of Set 14 | teeli
# Processing Record 50 of Set 14 | santa cruz de la palma
# Processing Record 1 of Set 15 | tarut
# Processing Record 2 of Set 15 | puerto leguizamo
# Processing Record 3 of Set 15 | necochea
# Processing Record 4 of Set 15 | bayan
# Processing Record 5 of Set 15 | kedgwick
# Processing Record 6 of Set 15 | sevsk
# Processing Record 7 of Set 15 | kostomuksha
# Processing Record 8 of Set 15 | naze
# Processing Record 9 of Set 15 | nichinan
# Processing Record 10 of Set 15 | greystones
# Processing Record 11 of Set 15 | lipari
# Processing Record 12 of Set 15 | mao
# Processing Record 13 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 15 | broome
# Processing Record 15 of Set 15 | caceres
# Processing Record 16 of Set 15 | cap-aux-meules
# Processing Record 17 of Set 15 | kiama
# Processing Record 18 of Set 15 | wanning
# Processing Record 19 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 15 | zapadnaya dvina
# Processing Record 21 of Set 15 | pinerovka
# Processing Record 22 of Set 15 | sorgun
# Processing Record 23 of Set 15 | kahama
# Processing Record 24 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 15 | anchorage
# Processing Record 26 of Set 15 | craig
# Processing Record 27 of Set 15 | porto nacional
# Processing Record 28 of Set 15 | nordhausen
# Processing Record 29 of Set 15 | namatanai
# Processing Record 30 of Set 15 | junin
# Processing Record 31 of Set 15 | trairi
# Processing Record 32 of Set 15 | seymchan
# Processing Record 33 of Set 15 | sorland
# Processing Record 34 of Set 15 | ciudad bolivar
# Processing Record 35 of Set 15 | tuni
# Processing Record 36 of Set 15 | tevriz
# Processing Record 37 of Set 15 | pavda
# City not found. Skipping...
# Processing Record 38 of Set 15 | kajaani
# Processing Record 39 of Set 15 | kuopio
# Processing Record 40 of Set 15 | khalkhal
# Processing Record 41 of Set 15 | baghdad
# Processing Record 42 of Set 15 | hede
# Processing Record 43 of Set 15 | saint-pierre
# Processing Record 44 of Set 15 | menongue
# Processing Record 45 of Set 15 | sohbatpur
# Processing Record 46 of Set 15 | los andes
# Processing Record 47 of Set 15 | ixtapa
# Processing Record 48 of Set 15 | tahta
# Processing Record 49 of Set 15 | svencioneliai
# Processing Record 50 of Set 15 | sistranda
# Processing Record 1 of Set 16 | kieta
# Processing Record 2 of Set 16 | anahuac
# Processing Record 3 of Set 16 | ponto novo
# Processing Record 4 of Set 16 | bilma
# Processing Record 5 of Set 16 | abakaliki
# Processing Record 6 of Set 16 | nagua
# Processing Record 7 of Set 16 | lucea
# Processing Record 8 of Set 16 | svetlogorsk
# Processing Record 9 of Set 16 | synya
# Processing Record 10 of Set 16 | blagoyevo
# Processing Record 11 of Set 16 | hilton head island
# Processing Record 12 of Set 16 | nauta
# Processing Record 13 of Set 16 | olafsvik
# Processing Record 14 of Set 16 | killybegs
# Processing Record 15 of Set 16 | belyy yar
# Processing Record 16 of Set 16 | carballo
# Processing Record 17 of Set 16 | atlantic city
# Processing Record 18 of Set 16 | ambulu
# Processing Record 19 of Set 16 | abrau-dyurso
# Processing Record 20 of Set 16 | yangjiang
# Processing Record 21 of Set 16 | pochutla
# Processing Record 22 of Set 16 | sinnamary
# Processing Record 23 of Set 16 | mecca
# Processing Record 24 of Set 16 | anadyr
# Processing Record 25 of Set 16 | payo
# Processing Record 26 of Set 16 | lakselv
# Processing Record 27 of Set 16 | bocaiuva
# Processing Record 28 of Set 16 | ximei
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#make sure at least 500 responses
len(city_data)
# Out:
# 719

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head(20)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Atar  20.5169  -13.0499     72.00        29          62
# 1     Chokurdakh  70.6333  147.9167    -14.62        94          88
# 2     Champerico  14.3000  -91.9167     80.35        80          69
# 3      Busselton -33.6500  115.3333     69.04        48           3
# 4        Socorro  31.6546 -106.3033     71.89        27          20
# 5        Labuhan  -6.8844  112.2051     87.28        61         100
# 6        Manggar  -2.8833  108.2667     86.16        65          99
# 7        Mataura -46.1927  168.8643     72.90        40         100
# 8           Moba  33.2288  105.0179     27.03        81          49
# 9          Aswan  24.0934   32.9070     74.70        34           0
# 10          Nara  34.6851  135.8049     72.50        43          93
# 11     Jamestown  42.0970  -79.2353     48.72        87           1
# 12     Hithadhoo  -0.6000   73.0833     82.24        72          98
# 13         Avera  33.1940  -82.5271     53.47        51           0
# 14     Kapchorwa   1.3965   34.4509     59.61        80         100
# 15   Provideniya  64.3833 -173.3000     17.71        73          75
# 16    Nikolskoye  59.7035   30.7861     38.01        97         100
# 17      Petrykiv  49.5332   25.5809     38.48        81         100
# 18    Whitehorse  60.7161 -135.0538     14.31        85          36
# 19  Puerto Ayora  -0.7393  -90.3518     69.51        81          45
#
#     Wind Speed Country Current Description
# 0         5.86      MR       broken clouds
# 1         6.46      RU     overcast clouds
# 2         1.34      GT       broken clouds
# 3        10.04      AU           clear sky
# 4         6.91      US          few clouds
# 5         3.69      ID     overcast clouds
# 6         3.58      ID     overcast clouds
# 7         1.14      NZ     overcast clouds
# 8         3.29      CN    scattered clouds
# 9         8.16      EG           clear sky
# 10       15.48      JP     overcast clouds
# 11        1.99      US           clear sky
# 12       13.00      MV     overcast clouds
# 13        6.82      US           clear sky
# 14        2.75      UG          light rain
# 15        4.47      RU       broken clouds
# 16        9.73      RU       moderate rain
# 17        9.84      UA     overcast clouds
# 18        4.00      CA    scattered clouds
# 19        8.12      EC    scattered clouds

# %%
#Create the output csv
output_data_file = "WeatherPy_Database.csv"
#Export the csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
